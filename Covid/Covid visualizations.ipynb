# %%
# %matplotlib notebook

# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
covid_df = pd.read_csv("US_covid.csv")
covid_df.head()
# Out:
#      Date                   Country  New Cases  Cumulative Cases  New Deaths  \
# 0  1/3/20  United States of America          0                 0           0
# 1  1/4/20  United States of America          0                 0           0
# 2  1/5/20  United States of America          0                 0           0
# 3  1/6/20  United States of America          0                 0           0
# 4  1/7/20  United States of America          0                 0           0
#
#    Cumulative Deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
covid_df_1 = covid_df.iloc[:472,:]
covid_df_2 = covid_df.iloc[472:,:]

# %%
covid_df_1.tail()
# Out:
#         Date                   Country  New Cases  Cumulative Cases  \
# 467  4/14/21  United States of America          0          30829825
# 468  4/15/21  United States of America          0          30829825
# 469  4/16/21  United States of America     491639          31321464
# 470  4/17/21  United States of America          0          31321464
# 471  4/18/21  United States of America          0          31321464
#
#      New Deaths  Cumulative Deaths
# 467           0             556505
# 468           0             556505
# 469        5264             561769
# 470           0             561769
# 471           0             561769

# %%
covid_df_2.head()
# Out:
#         Date                   Country  New Cases  Cumulative Cases  \
# 472  4/19/21  United States of America          0          31321464
# 473  4/20/21  United States of America          0          31321464
# 474  4/21/21  United States of America          0          31321464
# 475  4/22/21  United States of America          0          31321464
# 476  4/23/21  United States of America     438557          31760021
#
#      New Deaths  Cumulative Deaths
# 472           0             561769
# 473           0             561769
# 474           0             561769
# 475           0             561769
# 476        4996             566765

# %%
covid_df_1.plot(kind='line')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
covid_df_2.plot(kind='line')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
